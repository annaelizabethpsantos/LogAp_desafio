# %% [markdown]
# <a href="https://colab.research.google.com/github/annaelizabethpsantos/LogAp_desafio/blob/main/Plotagem_dos_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ler o arquivo CSV e plotar

import matplotlib.pyplot as plt
import pandas as pd
import csv

csvfile = open('/content/Abr-2017-curva-potencia-windbox.csv', 'r')
#spamreader = csv.reader(csvfile, delimiter=';')

x = []
y = []

for line in csvfile:
  line = line.strip()
  X, Y = line.split(';')
  x.append(X)
  y.append(Y)
plt.title('Curva de Potência ABRIL')
plt.scatter(x, y, color='blue')
plt.xlabel("Velocidade do Vento")
plt.ylabel("Potência")
plt.show()

# %%
#ler o arquivo CSV e plotar

import matplotlib.pyplot as plt
import pandas as pd
import csv

csvfile = open('/content/Mai-2017-curva-potencia-windbox.csv', 'r')
#spamreader = csv.reader(csvfile, delimiter=';')

x = []
y = []

for line in csvfile:
  line = line.strip()
  X, Y = line.split(';')
  x.append(X)
  y.append(Y)
plt.title('Curva de Potência MAIO')
plt.scatter(x, y, color='blue')
plt.xlabel("Velocidade do Vento")
plt.ylabel("Potência")
plt.show()

# %%
#ler o arquivo CSV e plotar

import matplotlib.pyplot as plt
import pandas as pd
import csv

csvfile = open('/content/Nov-2017-curva-potencia-windbox.csv', 'r')
#spamreader = csv.reader(csvfile, delimiter=';')

x = []
y = []

for line in csvfile:
  line = line.strip()
  X, Y = line.split(';')
  x.append(X)
  y.append(Y)
plt.title('Curva de Potência NOVEMBRO')
plt.scatter(x, y, color='blue')
plt.xlabel("Velocidade do Vento")
plt.ylabel("Potência")
plt.show()
